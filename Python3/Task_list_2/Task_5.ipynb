# %%
import numpy as np
import matplotlib.pyplot as plt
import sys

sys.path.insert(1, "..")
from packages.basicDistributionFunctions import characterist_r_i, CDF2
from packages.alphastable import multivariate_alphastable, get_alpha_cdf, get_alpha_char

# %%
Image_width = 10
if 0:
    plt.rc('text', usetex = True) # latex ticks
    plt.rc('text.latex')
    plt.rcParams['axes.unicode_minus'] = False
    plt.rcParams.update({
        "text.usetex": True,
        "font.family": "serif",
        "font.serif": ['Computer Modern'],
    })

    EXTRA_SMALL = 10
    SMALL_SIZE = 12
    MEDIUM_SIZE = 15
    BIGGER_SIZE = 20

    plt.rc('font', size=EXTRA_SMALL)         # controls default text sizes
    plt.rc('axes', titlesize=BIGGER_SIZE)    # fontsize of the axes title
    plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
    plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
    plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
N = 10 ** 4
gamma = [0.25, 0.125, 0.25, 0.25, 0.125, 0.25]
points = [[1, 0], [0.5, np.sqrt(3)/2],
            [-1/2, np.sqrt(3)/2], [-1, 0],
            [-1/2, -np.sqrt(3)/2], [1/2, -np.sqrt(3)/2]] 
alpha = 0.5
MA = multivariate_alphastable(alpha, gamma, points, N)
t = np.linspace(0.01, 3, N)
Re = characterist_r_i(t, MA[:, 0])[0]

N = len(MA[:, 0])
[sorted_X, ecdf] = CDF2(MA[:, 0])
ecdf_cut = ecdf[-int(0.1 * N):-1]
X_cut = sorted_X[-int(0.1 * N):-1]
Y = np.log(1 - ecdf_cut)

# %%
fig, axs = plt.subplots(nrows = 2, figsize = (Image_width, Image_width * 1.3))
ax = axs[0]
ax.plot(np.log(t), np.log(-np.log(np.abs(Re))))
ax.set_title("Illustration for the characteristic function method")
ax.set_xlabel("$\log(t)$")
ax.set_ylabel("$\log(-\log(|Re(\\varphi)|))$")

ax = axs[1]
ax.plot(np.log(X_cut), Y)
ax.set_title("Illustration for the CDF tail method")
ax.set_xlabel("$\log(x)$")
ax.set_ylabel("$\log(1 - F)$");

# %%
get_alpha_char(MA[:, 0], t)
# Out:
# (0.49919925580073715, 0.03505085327170493)

# %%
get_alpha_cdf(MA[:, 0], 0.1)
# Out:
# 0.49166918768278134

# %% [markdown]
# ## Gamma estimation

# %%
n = 30
E = np.arange(0, 2*np.pi, np.pi / n)
R = np.arange(10, 60, 5)
Gamma = np.ones((len(E), len(R)))
Gamma[:] = np.nan

for k in range(len(E)):
    e = E[k]
    for j in range(len(R)):
        r = R[j]
        counter_1 = 0
        counter_2 = 0
        for i in range(len(MA)):
            if np.arctan2(MA[i][1], MA[i][0]) < e and np.linalg.norm(MA[i]) > r:
                counter_1 += 1
            if np.linalg.norm(MA[i]) > r:
                counter_2 += 1
        if counter_2 != 0:
            Gamma[k, j] = counter_1 / counter_2

# %%
fig = plt.figure(figsize = (2 * Image_width, Image_width))
Points_angles = np.ones(N)
Points_radius = np.ones(N)
for i, val in enumerate(MA):
    Points_angles[i] = np.arctan2(MA[i][1], MA[i][0]) # first one is  y coordinate and the second is x coordinate
    Points_radius[i] = np.linalg.norm(MA[i])
ax1 = fig.add_subplot(121)
ax1.hist(Points_angles)
ax1.set_title("Histogram for sub Gaussian r.v. angles")
ax1.set_xlabel("angle")
ax1.set_ylabel("distribution")

ax2 = fig.add_subplot(122, polar = True)
rbins = np.linspace(0, Points_radius.max(), 50)
abins = np.linspace(-np.pi, np.pi, 60)
hist, _, _ = np.histogram2d(Points_angles, Points_radius, bins = (abins, rbins))
Angles, Rad = np.meshgrid(abins, rbins)
ax2.grid(False)
pc = ax2.pcolormesh(Angles, Rad, hist.T, cmap = "magma_r")
ax2.set_ylim([0, 25])
ax2.set_title("Polar histogram for multivariate alpha stable r.v.")
fig.colorbar(pc);
